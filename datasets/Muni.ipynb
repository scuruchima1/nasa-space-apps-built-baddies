# %%
import pandas as pd
df = pd.read_csv("Muni_25_chi_csv.csv")
print(df)
# Out:
#        GEOID               GEOG  F2000_POP  F2010_POP  F2020_POP  F2020_HH  \
# 0    1700243            Addison    35914.0    36942.0    35702.0   12296.0
# 1    1700685          Algonquin    23276.0    30046.0    29700.0   10769.0
# 2    1701010              Alsip    19725.0    19277.0    19063.0    7692.0
# 3    1701595            Antioch     8788.0    14430.0    14622.0    5265.0
# 4    1702154  Arlington Heights    76031.0    75101.0    77676.0   31782.0
# ..       ...                ...        ...        ...        ...       ...
# 279  1783245          Woodridge    30934.0    32971.0    34158.0   13468.0
# 280  1783349          Woodstock    20151.0    24770.0    25630.0    9807.0
# 281  1783518              Worth    11047.0    10789.0    10970.0    4416.0
# 282  1784038          Yorkville     6189.0    16921.0    21533.0    7414.0
# 283  1784220               Zion    22866.0    24413.0    24655.0    8542.0
#
# ...
