# %%
import pandas as pd
df = pd.read_csv("Food Access Research Atlas.csv")
df = df[(df["State"] == "Illinois") & (df["County"] == "Cook County" )]
df
# Out:
#        CensusTract     State       County  Urban  Pop2010  OHU2010  \
# 20935  17031010100  Illinois  Cook County      1     4854     2302
# 20936  17031010201  Illinois  Cook County      1     6450     2463
# 20937  17031010202  Illinois  Cook County      1     2818     1115
# 20938  17031010300  Illinois  Cook County      1     6236     2826
# 20939  17031010400  Illinois  Cook County      1     5042     2098
# ...            ...       ...          ...    ...      ...      ...
# 22244  17031843500  Illinois  Cook County      1    11309      278
# 22245  17031843600  Illinois  Cook County      1     2807     1169
# 22246  17031843700  Illinois  Cook County      1     2117      920
# 22247  17031843800  Illinois  Cook County      1     2110      651
# 22248  17031843900  Illinois  Cook County      1     3533     1935
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 20935                  0     218.0      4.49                  0  ...
# ...
